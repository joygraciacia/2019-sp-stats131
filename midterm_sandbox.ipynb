# %%
import pandas as pd
import numpy as np

# %%
bmx = pd.read_sas('BMX_I.XPT')

# %%
bmx.head()
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT    ...     BMXARMC  BMIARMC  BMXWAIST  BMIWAIST  BMXSAD1  \
# 0  184.5    NaN    ...        35.9      NaN     101.1       NaN     22.9
# 1  171.4    NaN    ...        33.2      NaN     107.9       NaN     27.5
# 2  170.1    NaN    ...        31.0      NaN     116.5       NaN     26.7
# 3  160.9    NaN    ...        38.3      NaN     110.1       NaN     25.2
# 4  164.9    NaN    ...        27.2      NaN      80.4       NaN      NaN
#
#    BMXSAD2  BMXSAD3  BMXSAD4  BMDAVSAD  BMDSADCM
# ...

# %%
bmx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 26 columns):
# SEQN        9544 non-null float64
# BMDSTATS    9544 non-null float64
# BMXWT       9445 non-null float64
# BMIWT       443 non-null float64
# BMXRECUM    1073 non-null float64
# BMIRECUM    33 non-null float64
# BMXHEAD     215 non-null float64
# BMIHEAD     0 non-null float64
# BMXHT       8769 non-null float64
# BMIHT       105 non-null float64
# BMXBMI      8756 non-null float64
# BMDBMIC     3340 non-null float64
# BMXLEG      7110 non-null float64
# BMILEG      402 non-null float64
# BMXARML     8976 non-null float64
# BMIARML     420 non-null float64
# BMXARMC     8976 non-null float64
# BMIARMC     421 non-null float64
# BMXWAIST    8313 non-null float64
# BMIWAIST    489 non-null float64
# BMXSAD1     6983 non-null float64
# BMXSAD2     6983 non-null float64
# BMXSAD3     353 non-null float64
# BMXSAD4     353 non-null float64
# BMDAVSAD    6983 non-null float64
# ...

# %% [markdown]
# ## Question 2

# %%
#a 
#bmx.loc[:,'BMXHT']
#bmx.loc[:,'BMXLEG']
print(bmx.loc[:,['BMXHT','BMXLEG']].corr())
#0.818352
# Out:
#            BMXHT    BMXLEG
# BMXHT   1.000000  0.818352
# BMXLEG  0.818352  1.000000

# %%
print(bmx.loc[:,['BMXHT','BMXARML']].corr())
#0.96258
# Out:
#            BMXHT  BMXARML
# BMXHT    1.00000  0.96258
# BMXARML  0.96258  1.00000

# %%
print(bmx.loc[:,['BMXLEG','BMXARML']].corr())
#0.713446
# Out:
#            BMXLEG   BMXARML
# BMXLEG   1.000000  0.713446
# BMXARML  0.713446  1.000000

# %%
bmx.head
# Out:
# <bound method NDFrame.head of          SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0     83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1     83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2     83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3     83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4     83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
# 5     83737.0       1.0   64.4    NaN       NaN       NaN      NaN      NaN
# 6     83738.0       1.0   37.2    NaN       NaN       NaN      NaN      NaN
# 7     83739.0       1.0   16.4    NaN       NaN       NaN      NaN      NaN
# 8     83740.0       3.0   10.1    NaN       NaN       1.0      NaN      NaN
# 9     83741.0       1.0   76.6    NaN       NaN       NaN      NaN      NaN
# 10    83742.0       1.0   64.5    NaN       NaN       NaN      NaN      NaN
# ...

# %%
demo = pd.read_sas('DEMO_I.XPT')

# %%
demo.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN    ...          5.0       1.0       3.0
# 1       3.0       1.0       NaN    ...          3.0       3.0       NaN
# 2       3.0       2.0       NaN    ...          3.0       1.0       3.0
# 3       3.0       2.0       NaN    ...          5.0       6.0       NaN
# 4       4.0       2.0       NaN    ...          4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9971 entries, 0 to 9970
# Data columns (total 47 columns):
# SEQN        9971 non-null float64
# SDDSRVYR    9971 non-null float64
# RIDSTATR    9971 non-null float64
# RIAGENDR    9971 non-null float64
# RIDAGEYR    9971 non-null float64
# RIDAGEMN    695 non-null float64
# RIDRETH1    9971 non-null float64
# RIDRETH3    9971 non-null float64
# RIDEXMON    9544 non-null float64
# RIDEXAGM    4060 non-null float64
# DMQMILIZ    6149 non-null float64
# DMQADFC     527 non-null float64
# DMDBORN4    9971 non-null float64
# DMDCITZN    9969 non-null float64
# DMDYRSUS    2236 non-null float64
# DMDEDUC3    2647 non-null float64
# DMDEDUC2    5719 non-null float64
# DMDMARTL    5719 non-null float64
# RIDEXPRG    1288 non-null float64
# SIALANG     9971 non-null float64
# SIAPROXY    9970 non-null float64
# SIAINTRP    9971 non-null float64
# FIALANG     9642 non-null float64
# FIAPROXY    9642 non-null float64
# ...

# %%
merged = bmx.merge(right = demo, on = 'SEQN')

# %%
print(merged.head())
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT    ...     DMDHREDU  DMDHRMAR  DMDHSEDU       WTINT2YR  \
# 0  184.5    NaN    ...          5.0       1.0       3.0  134671.370419
# 1  171.4    NaN    ...          3.0       3.0       NaN   24328.560239
# 2  170.1    NaN    ...          3.0       1.0       3.0   12400.008522
# 3  160.9    NaN    ...          5.0       6.0       NaN  102717.995647
# 4  164.9    NaN    ...          4.0       3.0       NaN   17627.674984
#
#         WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %%
merged.loc[:,'RIDAGEYR']
# Out:
# 0       62.0
# 1       53.0
# 2       78.0
# 3       56.0
# 4       42.0
# 5       72.0
# 6       11.0
# 7        4.0
# 8        1.0
# 9       22.0
# 10      32.0
# 11      18.0
# 12      56.0
# 13      15.0
# 14       4.0
# 15      46.0
# 16       3.0
# 17      17.0
# 18      45.0
# 19      16.0
# 20      30.0
# 21      15.0
# 22      67.0
# 23      67.0
# 24      16.0
# 25      57.0
# 26      19.0
# 27       3.0
# 28      24.0
# 29      27.0
#         ...
# 9514    63.0
# 9515     5.0
# 9516     8.0
# 9517    38.0
# 9518    35.0
# 9519    34.0
# 9520     1.0
# 9521    72.0
# 9522    17.0
# 9523    41.0
# 9524     3.0
# 9525    34.0
# 9526    53.0
# 9527    13.0
# 9528    16.0
# 9529     1.0
# 9530    69.0
# 9531    32.0
# 9532    25.0
# 9533     1.0
# 9534     7.0
# 9535     7.0
# 9536    76.0
# 9537    26.0
# 9538    80.0
# 9539     2.0
# 9540     6.0
# 9541    35.0
# 9542     8.0
# 9543    24.0
# Name: RIDAGEYR, Length: 9544, dtype: float64

# %%
bins = pd.IntervalIndex.from_tuples([(20, 29.9), (30, 39.9), (40, 49.9), (50,59.9), (60,69.9), (70,79.9),(80,200)]
                            )
thing=pd.cut(merged.loc[:,'RIDAGEYR'],bins,right=False)

thing=pd.DataFrame(thing)

merged['RIDAGEYR']=thing

merged.head()

merged.loc[:,['BMXHT','DMDHREDU','DMDHRMAR']].groupby(merged.RIDAGEYR).mean()
# Out:
#                    BMXHT  DMDHREDU  DMDHRMAR
# RIDAGEYR
# (20.0, 29.9]  167.636568  3.625310  3.439340
# (30.0, 39.9]  167.483836  3.525340  2.719235
# (40.0, 49.9]  166.458108  3.556533  2.343941
# (50.0, 59.9]  166.460924  3.480670  2.319652
# (60.0, 69.9]  164.756290  3.344114  2.478697
# (70.0, 79.9]  164.197386  3.337691  2.311301

# %%
data_new=merged.loc[:,['BMXHT','BMXLEG','BMXARML']].groupby(merged.RIDAGEYR).mean()
data_new
# Out:
#                    BMXHT     BMXLEG    BMXARML
# RIDAGEYR
# (20.0, 29.9]  167.636568  40.015129  37.051408
# (30.0, 39.9]  167.483836  39.582188  37.194823
# (40.0, 49.9]  166.458108  38.694689  37.105928
# (50.0, 59.9]  166.460924  38.139637  37.226215
# (60.0, 69.9]  164.756290  37.248928  37.193045
# (70.0, 79.9]  164.197386  36.883816  37.290164

# %%
import matplotlib.pyplot as plt

# %%
data_new['BMXHT']=data_new.loc[:,['BMXHT']]-128

# %%
data_new.plot.line()

# %%
data_new.shape
# Out:
# (6, 3)

# %%
q3=demo.loc[:,['INDHHIN2','DMDHREDU']]
q3[demo.loc[:,['RIDAGEYR']]>=20]
#q3=q3.loc[:,['INDHHIN2','DMDHREDU']]
q3

#
criteria=demo.loc[:,['RIDAGEYR']]>=20
criteria=criteria.values.tolist()
#print(criteria)

q3=q3[criteria]
q3=q3.dropna()
print(q3)


criteria1=q3.loc[:,['INDHHIN2']]>=20000&q3.loc[:,['INDHHIN2']]<20000

criteria1=criteria1.values.tolist()

q3=q3[criteria1]
print(q3)
# Out:
#       INDHHIN2  DMDHREDU
# 0         10.0       5.0
# 1          4.0       3.0
# 2          5.0       3.0
# 3         10.0       5.0
# 4          7.0       4.0
# 5         14.0       5.0
# 9          7.0       4.0
# 10         6.0       4.0
# 12         3.0       3.0
# 15         3.0       5.0
# 20        15.0       5.0
# 22         6.0       5.0
# 23         5.0       5.0
# 25         5.0       1.0
# 26         9.0       5.0
# 29         1.0       5.0
# 30         8.0       3.0
# 35        14.0       4.0
# 37        10.0       2.0
# 41         7.0       3.0
# 43         2.0       1.0
# 44        14.0       5.0
# 45         7.0       2.0
# 49        77.0       5.0
# 54        77.0       5.0
# 55         4.0       1.0
# 56         7.0       5.0
# 57        10.0       5.0
# 58         4.0       3.0
# 59        12.0       2.0
# ...        ...       ...
# 9913       4.0       5.0
# 9919      15.0       5.0
# 9920       3.0       2.0
# 9921      14.0       5.0
# 9922      99.0       5.0
# ...

# %%
q3.shape
# Out:
# (5349, 2)

# %%
q3.corr()
# Out:
#           INDHHIN2  DMDHREDU
# INDHHIN2  1.000000  0.051312
# DMDHREDU  0.051312  1.000000

# %%
matplotlib.pyplot.scatter()

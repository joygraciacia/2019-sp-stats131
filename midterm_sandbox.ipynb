# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bmx = pd.read_sas('BMX_I.XPT')

# %%
bmx.head()
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT    ...     BMXARMC  BMIARMC  BMXWAIST  BMIWAIST  BMXSAD1  \
# 0  184.5    NaN    ...        35.9      NaN     101.1       NaN     22.9
# 1  171.4    NaN    ...        33.2      NaN     107.9       NaN     27.5
# 2  170.1    NaN    ...        31.0      NaN     116.5       NaN     26.7
# 3  160.9    NaN    ...        38.3      NaN     110.1       NaN     25.2
# 4  164.9    NaN    ...        27.2      NaN      80.4       NaN      NaN
#
#    BMXSAD2  BMXSAD3  BMXSAD4  BMDAVSAD  BMDSADCM
# ...

# %%
bmx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 26 columns):
# SEQN        9544 non-null float64
# BMDSTATS    9544 non-null float64
# BMXWT       9445 non-null float64
# BMIWT       443 non-null float64
# BMXRECUM    1073 non-null float64
# BMIRECUM    33 non-null float64
# BMXHEAD     215 non-null float64
# BMIHEAD     0 non-null float64
# BMXHT       8769 non-null float64
# BMIHT       105 non-null float64
# BMXBMI      8756 non-null float64
# BMDBMIC     3340 non-null float64
# BMXLEG      7110 non-null float64
# BMILEG      402 non-null float64
# BMXARML     8976 non-null float64
# BMIARML     420 non-null float64
# BMXARMC     8976 non-null float64
# BMIARMC     421 non-null float64
# BMXWAIST    8313 non-null float64
# BMIWAIST    489 non-null float64
# BMXSAD1     6983 non-null float64
# BMXSAD2     6983 non-null float64
# BMXSAD3     353 non-null float64
# BMXSAD4     353 non-null float64
# BMDAVSAD    6983 non-null float64
# ...

# %%
bmx.head
# Out:
# <bound method NDFrame.head of          SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0     83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1     83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2     83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3     83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4     83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
# 5     83737.0       1.0   64.4    NaN       NaN       NaN      NaN      NaN
# 6     83738.0       1.0   37.2    NaN       NaN       NaN      NaN      NaN
# 7     83739.0       1.0   16.4    NaN       NaN       NaN      NaN      NaN
# 8     83740.0       3.0   10.1    NaN       NaN       1.0      NaN      NaN
# 9     83741.0       1.0   76.6    NaN       NaN       NaN      NaN      NaN
# 10    83742.0       1.0   64.5    NaN       NaN       NaN      NaN      NaN
# ...

# %%
demo = pd.read_sas('DEMO_I.XPT')

# %%
demo.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN    ...          5.0       1.0       3.0
# 1       3.0       1.0       NaN    ...          3.0       3.0       NaN
# 2       3.0       2.0       NaN    ...          3.0       1.0       3.0
# 3       3.0       2.0       NaN    ...          5.0       6.0       NaN
# 4       4.0       2.0       NaN    ...          4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9971 entries, 0 to 9970
# Data columns (total 47 columns):
# SEQN        9971 non-null float64
# SDDSRVYR    9971 non-null float64
# RIDSTATR    9971 non-null float64
# RIAGENDR    9971 non-null float64
# RIDAGEYR    9971 non-null float64
# RIDAGEMN    695 non-null float64
# RIDRETH1    9971 non-null float64
# RIDRETH3    9971 non-null float64
# RIDEXMON    9544 non-null float64
# RIDEXAGM    4060 non-null float64
# DMQMILIZ    6149 non-null float64
# DMQADFC     527 non-null float64
# DMDBORN4    9971 non-null float64
# DMDCITZN    9969 non-null float64
# DMDYRSUS    2236 non-null float64
# DMDEDUC3    2647 non-null float64
# DMDEDUC2    5719 non-null float64
# DMDMARTL    5719 non-null float64
# RIDEXPRG    1288 non-null float64
# SIALANG     9971 non-null float64
# SIAPROXY    9970 non-null float64
# SIAINTRP    9971 non-null float64
# FIALANG     9642 non-null float64
# FIAPROXY    9642 non-null float64
# ...

# %%
merged = bmx.merge(right = demo, on = 'SEQN')

# %%
print(merged.head())
merged.loc[:,'SEQN']
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT    ...     DMDHREDU  DMDHRMAR  DMDHSEDU       WTINT2YR  \
# 0  184.5    NaN    ...          5.0       1.0       3.0  134671.370419
# 1  171.4    NaN    ...          3.0       3.0       NaN   24328.560239
# 2  170.1    NaN    ...          3.0       1.0       3.0   12400.008522
# 3  160.9    NaN    ...          5.0       6.0       NaN  102717.995647
# 4  164.9    NaN    ...          4.0       3.0       NaN   17627.674984
#
#         WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %% [markdown]
# # Question 1

# %%
boy=merged[merged.loc[:,'RIDAGEMN']<13]
boy=boy[boy.loc[:,'RIAGENDR']==1]
boy=boy.groupby(['RIDAGEMN'])
boy=boy['BMXWT'].mean()
print(boy)
# Out:
# RIDAGEMN
# 5.397605e-79     4.794444
# 1.000000e+00     5.791667
# 2.000000e+00     6.661111
# 3.000000e+00     7.000000
# 4.000000e+00     7.795000
# 5.000000e+00     8.525000
# 6.000000e+00     8.263636
# 7.000000e+00     9.061111
# 8.000000e+00     9.322222
# 9.000000e+00    10.093750
# 1.000000e+01    10.364286
# 1.100000e+01     9.963636
# 1.200000e+01    10.523077
# Name: BMXWT, dtype: float64

# %%
girl=merged[merged.loc[:,'RIDAGEMN']<13]
girl=girl[girl.loc[:,'RIAGENDR']==2]
girl=girl.groupby(['RIDAGEMN'])
girl=girl['BMXWT'].mean()
print(girl)
# Out:
# RIDAGEMN
# 5.397605e-79    4.508333
# 1.000000e+00    5.457143
# 2.000000e+00    5.712500
# 3.000000e+00    6.553846
# 4.000000e+00    7.052941
# 5.000000e+00    7.647059
# 6.000000e+00    8.005263
# 7.000000e+00    8.190909
# 8.000000e+00    8.303704
# 9.000000e+00    9.243750
# 1.000000e+01    9.066667
# 1.100000e+01    9.100000
# 1.200000e+01    9.757143
# Name: BMXWT, dtype: float64

# %%
boy-girl
# Out:
# RIDAGEMN
# 5.397605e-79    0.286111
# 1.000000e+00    0.334524
# 2.000000e+00    0.948611
# 3.000000e+00    0.446154
# 4.000000e+00    0.742059
# 5.000000e+00    0.877941
# 6.000000e+00    0.258373
# 7.000000e+00    0.870202
# 8.000000e+00    1.018519
# 9.000000e+00    0.850000
# 1.000000e+01    1.297619
# 1.100000e+01    0.863636
# 1.200000e+01    0.765934
# Name: BMXWT, dtype: float64

# %%
plt.plot(girl.index,girl)
plt.plot(boy.index,boy)
plt.xlabel('Month')
plt.ylabel('Weight')
# Out:
# Text(0,0.5,'Weight')

# %%
boy=pd.DataFrame(boy)
print(boy)
# Out:
#                   BMXWT
# RIDAGEMN
# 5.397605e-79   4.794444
# 1.000000e+00   5.791667
# 2.000000e+00   6.661111
# 3.000000e+00   7.000000
# 4.000000e+00   7.795000
# 5.000000e+00   8.525000
# 6.000000e+00   8.263636
# 7.000000e+00   9.061111
# 8.000000e+00   9.322222
# 9.000000e+00  10.093750
# 1.000000e+01  10.364286
# 1.100000e+01   9.963636
# 1.200000e+01  10.523077

# %%
import seaborn as sns

# %%
sea_data=merged.loc[merged.RIDAGEMN<13]
sea_data=merged.loc[:,['RIDAGEMN','RIAGENDR','BMXWT']]
#print(sea_data)

#female_data=sea_data.loc[sea_data.RIAGENDR==2]
#print(female_data)
#male_data=sea_data.loc[sea_data.RIAGENDR==1]
#print(male_data)

sns.lmplot(x="RIDAGEMN", y="BMXWT", hue="RIAGENDR", data=sea_data, lowess=True)
plt.ylim()

# %% [markdown]
# # Question 2

# %%
merged.loc[:,['BMXHT','BMXLEG']]
print(merged['BMXHT'].corr(merged['BMXLEG']))
# Out:
# 0.8183515685456074

# %%
print(merged['BMXHT'].corr(merged['BMXARML']))
# Out:
# 0.9625802870578782

# %%
print(merged['BMXLEG'].corr(merged['BMXARML']))
# Out:
# 0.713445914060824

# %%
merged['RIDAGEYR']

bins = pd.IntervalIndex.from_tuples([(20, 29.9), (30, 39.9), (40, 49.9), (50, 59.9), (60, 69.9), (70,79.9),(80,89.9)])
merged['cut-year']=pd.cut(merged['RIDAGEYR'], bins)

merged.groupby('cut-year')['BMDSTATS','BMXWT','BMXHT'].mean()
# Out:
#               BMDSTATS      BMXWT       BMXHT
# cut-year
# (20.0, 29.9]  1.185446  78.883688  167.636568
# (30.0, 39.9]  1.171633  84.798673  167.483836
# (40.0, 49.9]  1.123171  84.773587  166.458108
# (50.0, 59.9]  1.094410  83.280899  166.460924
# (60.0, 69.9]  1.169173  82.120382  164.756290
# (70.0, 79.9]  1.266525  79.122588  164.197386
# (80.0, 89.9]       NaN        NaN         NaN

# %%
merged.head()
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT      ...       DMDHRMAR  DMDHSEDU       WTINT2YR  \
# 0  184.5    NaN      ...            1.0       3.0  134671.370419
# 1  171.4    NaN      ...            3.0       NaN   24328.560239
# 2  170.1    NaN      ...            1.0       3.0   12400.008522
# 3  160.9    NaN      ...            6.0       NaN  102717.995647
# 4  164.9    NaN      ...            3.0       NaN   17627.674984
#
#         WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR  \
# ...

# %%
values=merged.groupby('cut-year')['BMXHT','BMXARML','BMXLEG'].mean()

# %%
x=values.index
y=values['BMXHT']
values['BMXHT']=values['BMXHT']-128
values.plot()
#plt.xlabel("Age Decade")
#plt.ylabel("Mean Measurement")
#plt.plot(x,y)
#plt.plot(values.index,merged['BMXARML'])
#plt.plot(values.index,merged['BMXLEG'])

#values.index
#values['BMXHT']
#merged['cut-year']

# %% [markdown]
# # Question 3

# %%
q3=merged.loc[merged.RIDAGEMN>20]

# %%
q3=q3.loc[:,['INDHHIN2','DMDHREDU']]
q3=q3.dropna(axis=0, how='any')
q3=pd.DataFrame(q3)

print(q3)
# Out:
#       INDHHIN2  DMDHREDU
# 45        99.0       3.0
# 153        4.0       4.0
# 171        7.0       1.0
# 514       10.0       4.0
# 599        5.0       4.0
# 758        1.0       3.0
# 952        8.0       3.0
# 1016       1.0       4.0
# 1154       4.0       1.0
# 1167       1.0       3.0
# 1187      14.0       5.0
# 1286       4.0       4.0
# 1377       2.0       4.0
# 1421      14.0       5.0
# 1426      14.0       3.0
# 1569       8.0       4.0
# 1583      15.0       5.0
# 1827      15.0       5.0
# 1937       9.0       4.0
# 2031       9.0       4.0
# 2087      15.0       5.0
# 2289       2.0       4.0
# 2386       7.0       2.0
# 2751      77.0       4.0
# 2755      13.0       4.0
# 2891      14.0       5.0
# 2984      14.0       4.0
# 2990      14.0       1.0
# 3200       3.0       1.0
# 3537       5.0       4.0
# ...        ...       ...
# 5837       1.0       9.0
# 5850       5.0       4.0
# 5860       7.0       4.0
# 5971       6.0       3.0
# 6139       6.0       2.0
# ...

# %%
result=(~(q3.loc[:,'INDHHIN2']==(12.0 or 13.0)))
print(result)
q3=q3.loc[result]
print(q3)
# Out:
# 45       True
# 153      True
# 171      True
# 514      True
# 599      True
# 758      True
# 952      True
# 1016     True
# 1154     True
# 1167     True
# 1187     True
# 1286     True
# 1377     True
# 1421     True
# 1426     True
# 1569     True
# 1583     True
# 1827     True
# 1937     True
# 2031     True
# 2087     True
# 2289     True
# 2386     True
# 2751     True
# 2755     True
# 2891     True
# 2984     True
# 2990     True
# 3200     True
# 3537     True
#         ...
# 5837     True
# 5850     True
# 5860     True
# 5971     True
# 6139     True
# 6149     True
# 6420     True
# 6541     True
# 6767     True
# 6858     True
# 6904     True
# 7183     True
# 7242     True
# 7321    False
# 7423     True
# 7779     True
# 7842     True
# 8029     True
# 8242     True
# 8310     True
# 8411     True
# 8412     True
# 8527     True
# 8538     True
# 8691    False
# 8825     True
# 9425    False
# 9429     True
# 9430     True
# 9472     True
# ...

# %%
q3.shape
# Out:
# (75, 2)

# %%
x=q3['INDHHIN2']
print(x)

y=q3['DMDHREDU']
print(y)

plt.scatter(x,y)
# Out:
# 45      99.0
# 153      4.0
# 171      7.0
# 514     10.0
# 599      5.0
# 758      1.0
# 952      8.0
# 1016     1.0
# 1154     4.0
# 1167     1.0
# 1187    14.0
# 1286     4.0
# 1377     2.0
# 1421    14.0
# 1426    14.0
# 1569     8.0
# 1583    15.0
# 1827    15.0
# 1937     9.0
# 2031     9.0
# 2087    15.0
# 2289     2.0
# 2386     7.0
# 2751    77.0
# 2755    13.0
# 2891    14.0
# 2984    14.0
# 2990    14.0
# 3200     3.0
# 3537     5.0
#         ...
# 5210     5.0
# 5279     4.0
# 5466     1.0
# 5837     1.0
# 5850     5.0
# 5860     7.0
# 5971     6.0
# 6139     6.0
# 6149     8.0
# 6420     7.0
# 6541    15.0
# 6767     7.0
# 6858    15.0
# 6904     5.0
# 7183     8.0
# 7242     6.0
# 7423     7.0
# 7779     9.0
# 7842     7.0
# 8029     9.0
# 8242     8.0
# 8310     3.0
# 8411     9.0
# 8412     7.0
# 8527    15.0
# 8538    15.0
# 8825     8.0
# 9429     9.0
# 9430    15.0
# 9472    15.0
# Name: INDHHIN2, Length: 75, dtype: float64
# 45      3.0
# 153     4.0
# ...

# %%
sns.boxplot(x="INDHHIN2", y="DMDHREDU", data=q3) # boxplots
